# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
vdf = pd.read_csv("beeActivity.csv")
vdf = vdf[vdf['group_id'] == 7]
vdf
# Out:
#       Unnamed: 0.1  Unnamed: 0  frame  det_id  track_id  tag_id  \
# 2475          2475       85659  13451       2      3029  1697.0
# 2476          2476       85661  13452       2      3029  1697.0
# 2477          2477       85663  13453       2      3029  1697.0
# 2478          2478       85665  13454       2      3029  1697.0
# 2479          2479       85667  13455       2      3029  1697.0
# ...            ...         ...    ...     ...       ...     ...
# 2640          2640       86355  13631       1      3042  1697.0
# 2641          2641       86358  13632       1      3042  1697.0
# 2642          2642       86361  13633       2      3042  1697.0
# 2643          2643       86364  13634       2      3042  1697.0
# 2644          2644       86367  13635       2      3042  1697.0
#
#                        video_name           cx           cy       angle  ...  \
# 2475  1_02_R_190807110000.cfr.mp4  1922.739868  1448.664673  -30.228004  ...
# ...

# %%
im = plt.imread("canvas.png")
implot = plt.imshow(im)
implot
